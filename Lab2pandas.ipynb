# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv(r'C:/Users/diana/OneDrive/Bureau/Labs/python_labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file1.csv')
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df1=df1.rename({'ST':'State', 'GENDER': 'Gender'}, axis=1)
df1
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2 = pd.read_csv(r'C:/Users/diana/OneDrive/Bureau/Labs/python_labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file2.csv')

df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df3 = pd.read_csv(r'C:/Users/diana/OneDrive/Bureau/Labs/python_labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file3.csv')
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
df2=df2.rename({'ST':'State', 'GENDER': 'Gender'}, axis=1)
df2
# Out:
#     Customer       State Gender Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df1.head (0)
# Out:
# Empty DataFrame
# Columns: [Customer, State, Gender, Education, Customer Lifetime Value, Income, Monthly Premium Auto, Number of Open Complaints, Policy Type, Vehicle Class, Total Claim Amount]
# Index: []

# %%
df2.head(0)
# Out:
# Empty DataFrame
# Columns: [Customer, State, Gender, Education, Customer Lifetime Value, Income, Monthly Premium Auto, Number of Open Complaints, Total Claim Amount, Policy Type, Vehicle Class]
# Index: []

# %%
df3.head(0)
# Out:
# Empty DataFrame
# Columns: [Customer, State, Customer Lifetime Value, Education, Gender, Income, Monthly Premium Auto, Number of Open Complaints, Policy Type, Total Claim Amount, Vehicle Class]
# Index: []

# %%
df2 = df2[['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value', 'Income', 'Monthly Premium Auto', 'Number of Open Complaints', 'Policy Type', 'Vehicle Class', 'Total Claim Amount']]

# %%
df2.head(0)
# Out:
# Empty DataFrame
# Columns: [Customer, State, Gender, Education, Customer Lifetime Value, Income, Monthly Premium Auto, Number of Open Complaints, Policy Type, Vehicle Class, Total Claim Amount]
# Index: []

# %%
df3 = df3[['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value', 'Income', 'Monthly Premium Auto', 'Number of Open Complaints', 'Policy Type', 'Vehicle Class', 'Total Claim Amount']]

# %%
df3.head(0)
# Out:
# Empty DataFrame
# Columns: [Customer, State, Gender, Education, Customer Lifetime Value, Income, Monthly Premium Auto, Number of Open Complaints, Policy Type, Vehicle Class, Total Claim Amount]
# Index: []

# %%
df=pd.concat([df1, df2, df3], ignore_index=True)

# %%
df
# Out:
#       Customer       State Gender             Education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# ...

# %%
select_dtypes=df.dtypes
df.dtypes
# Out:
# Customer                      object
# State                         object
# Gender                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
df_numerical=df.select_dtypes(include='number')
df_numerical
# Out:
#         Income  Monthly Premium Auto  Total Claim Amount
# 0          0.0                1000.0            2.704934
# 1          0.0                  94.0         1131.464935
# 2      48767.0                 108.0          566.472247
# 3          0.0                 106.0          529.881344
# 4      36357.0                  68.0           17.269323
# ...        ...                   ...                 ...
# 12069  71941.0                  73.0          198.234764
# 12070  21604.0                  79.0          379.200000
# 12071      0.0                  85.0          790.784983
# 12072  21941.0                  96.0          691.200000
# 12073      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %%
df_categorical=df.select_dtypes(exclude='number')
df_categorical
# Out:
#       Customer       State Gender             Education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       Customer Lifetime Value Number of Open Complaints     Policy Type  \
# 0                         NaN                    1/0/00   Personal Auto
# 1                  697953.59%                    1/0/00   Personal Auto
# 2                 1288743.17%                    1/0/00   Personal Auto
# ...

# %%
df=df.drop(['Education', 'Number of Open Complaints'], axis=1)
df
# Out:
#       Customer       State Gender Customer Lifetime Value   Income  \
# 0      RB50392  Washington    NaN                     NaN      0.0
# 1      QZ44356     Arizona      F              697953.59%      0.0
# 2      AI49188      Nevada      F             1288743.17%  48767.0
# 3      WW63253  California      M              764586.18%      0.0
# 4      GA49547  Washington      M              536307.65%  36357.0
# ...        ...         ...    ...                     ...      ...
# 12069  LA72316  California      M             23405.98798  71941.0
# 12070  PK87824  California      F             3096.511217  21604.0
# 12071  TD14365  California      M             8163.890428      0.0
# 12072  UP19263  California      M             7524.442436  21941.0
# 12073  Y167826  California      M             2611.836866      0.0
#
#        Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount
# 0                    1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
df['Customer Lifetime Value'] = df['Customer Lifetime Value'].astype(str).str.replace('%', '').astype(float)
df
# Out:
#       Customer       State Gender  Customer Lifetime Value   Income  \
# 0      RB50392  Washington    NaN                      NaN      0.0
# 1      QZ44356     Arizona      F             6.979536e+05      0.0
# 2      AI49188      Nevada      F             1.288743e+06  48767.0
# 3      WW63253  California      M             7.645862e+05      0.0
# 4      GA49547  Washington      M             5.363077e+05  36357.0
# ...        ...         ...    ...                      ...      ...
# 12069  LA72316  California      M             2.340599e+04  71941.0
# 12070  PK87824  California      F             3.096511e+03  21604.0
# 12071  TD14365  California      M             8.163890e+03      0.0
# 12072  UP19263  California      M             7.524442e+03  21941.0
# 12073  Y167826  California      M             2.611837e+03      0.0
#
#        Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount
# ...

# %%
df['Customer Lifetime Value'] = df['Customer Lifetime Value'] * 100
df
# Out:
#       Customer       State Gender  Customer Lifetime Value   Income  \
# 0      RB50392  Washington    NaN                      NaN      0.0
# 1      QZ44356     Arizona      F             6.979536e+07      0.0
# 2      AI49188      Nevada      F             1.288743e+08  48767.0
# 3      WW63253  California      M             7.645862e+07      0.0
# 4      GA49547  Washington      M             5.363076e+07  36357.0
# ...        ...         ...    ...                      ...      ...
# 12069  LA72316  California      M             2.340599e+06  71941.0
# 12070  PK87824  California      F             3.096511e+05  21604.0
# 12071  TD14365  California      M             8.163890e+05      0.0
# 12072  UP19263  California      M             7.524442e+05  21941.0
# 12073  Y167826  California      M             2.611837e+05      0.0
#
#        Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount
# ...

# %%
df.columns=df.columns.str.lower()
df.columns
# Out:
# Index(['customer', 'state', 'gender', 'customer lifetime value', 'income',
#        'monthly premium auto', 'policy type', 'vehicle class',
#        'total claim amount'],
#       dtype='object')

# %%
duplicateRows = df[df.duplicated()]
duplicateRows
# Out:
#      customer       state gender  customer lifetime value   income  \
# 1072      NaN         NaN    NaN                      NaN      NaN
# 1073      NaN         NaN    NaN                      NaN      NaN
# 1074      NaN         NaN    NaN                      NaN      NaN
# 1075      NaN         NaN    NaN                      NaN      NaN
# 1076      NaN         NaN    NaN                      NaN      NaN
# ...       ...         ...    ...                      ...      ...
# 4006      NaN         NaN    NaN                      NaN      NaN
# 4007      NaN         NaN    NaN                      NaN      NaN
# 4008  GS98873     Arizona      F               32391247.0  16061.0
# 4009  CW49887  California      F               46268011.0  79487.0
# 4010  MY31220  California      F               89970402.0  54230.0
#
#       monthly premium auto    policy type  vehicle class  total claim amount
# 1072                   NaN            NaN            NaN                 NaN
# ...

# %%
df = df.drop_duplicates(keep='first')
df
# Out:
#       customer       state gender  customer lifetime value   income  \
# 0      RB50392  Washington    NaN                      NaN      0.0
# 1      QZ44356     Arizona      F             6.979536e+07      0.0
# 2      AI49188      Nevada      F             1.288743e+08  48767.0
# 3      WW63253  California      M             7.645862e+07      0.0
# 4      GA49547  Washington      M             5.363076e+07  36357.0
# ...        ...         ...    ...                      ...      ...
# 12069  LA72316  California      M             2.340599e+06  71941.0
# 12070  PK87824  California      F             3.096511e+05  21604.0
# 12071  TD14365  California      M             8.163890e+05      0.0
# 12072  UP19263  California      M             7.524442e+05  21941.0
# 12073  Y167826  California      M             2.611837e+05      0.0
#
#        monthly premium auto     policy type  vehicle class  total claim amount
# ...

# %%
filtered_df = df[df['income'] <= 0]
filtered_df
# Out:
#       customer       state gender  customer lifetime value  income  \
# 0      RB50392  Washington    NaN                      NaN     0.0
# 1      QZ44356     Arizona      F             6.979536e+07     0.0
# 3      WW63253  California      M             7.645862e+07     0.0
# 7      CF85061     Arizona      M             7.216100e+07     0.0
# 10     SX51350  California      M             4.738992e+07     0.0
# ...        ...         ...    ...                      ...     ...
# 12063  WZ45103  California      F             5.678050e+05     0.0
# 12065  RX91025  California      M             1.987226e+06     0.0
# 12066  AC13887  California      M             4.628995e+05     0.0
# 12071  TD14365  California      M             8.163890e+05     0.0
# 12073  Y167826  California      M             2.611837e+05     0.0
#
#        monthly premium auto     policy type  vehicle class  total claim amount
# 0                    1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
df_info=df.info()
df_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9135 entries, 0 to 12073
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer                 9134 non-null   object
#  1   state                    9134 non-null   object
#  2   gender                   9012 non-null   object
#  3   customer lifetime value  9127 non-null   float64
#  4   income                   9134 non-null   float64
#  5   monthly premium auto     9134 non-null   float64
#  6   policy type              9134 non-null   object
#  7   vehicle class            9134 non-null   object
#  8   total claim amount       9134 non-null   float64
# dtypes: float64(4), object(5)
# memory usage: 713.7+ KB

# %%
df_sum=df.isna().sum()
df_sum
# Out:
# customer                     1
# state                        1
# gender                     123
# customer lifetime value      8
# income                       1
# monthly premium auto         1
# policy type                  1
# vehicle class                1
# total claim amount           1
# dtype: int64

# %%
select_dtypes=df.dtypes
df.dtypes
# Out:
# customer                    object
# state                       object
# gender                      object
# customer lifetime value    float64
# income                     float64
# monthly premium auto       float64
# policy type                 object
# vehicle class               object
# total claim amount         float64
# dtype: object

# %%
df_numerical=df.select_dtypes(include='number')
df_numerical
# Out:
#        customer lifetime value   income  monthly premium auto  \
# 0                          NaN      0.0                1000.0
# 1                 6.979536e+07      0.0                  94.0
# 2                 1.288743e+08  48767.0                 108.0
# 3                 7.645862e+07      0.0                 106.0
# 4                 5.363076e+07  36357.0                  68.0
# ...                        ...      ...                   ...
# 12069             2.340599e+06  71941.0                  73.0
# 12070             3.096511e+05  21604.0                  79.0
# 12071             8.163890e+05      0.0                  85.0
# 12072             7.524442e+05  21941.0                  96.0
# 12073             2.611837e+05      0.0                  77.0
#
#        total claim amount
# 0                2.704934
# 1             1131.464935
# 2              566.472247
# 3              529.881344
# 4               17.269323
# ...                   ...
# 12069          198.234764
# ...

# %%
df_sum_numerical=df_numerical.isna().sum()
df_sum_numerical
# Out:
# customer lifetime value    8
# income                     1
# monthly premium auto       1
# total claim amount         1
# dtype: int64

# %%
col_median=df["customer lifetime value"].dropna().median()
df["customer lifetime value"]=df["customer lifetime value"].fillna(col_median)
# Out:
# C:\Users\diana\AppData\Local\Temp\ipykernel_31912\189780145.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["customer lifetime value"]=df["customer lifetime value"].fillna(col_median)

# %%
df
# Out:
#       customer       state gender  customer lifetime value   income  \
# 0      RB50392  Washington    NaN             7.714624e+05      0.0
# 1      QZ44356     Arizona      F             6.979536e+07      0.0
# 2      AI49188      Nevada      F             1.288743e+08  48767.0
# 3      WW63253  California      M             7.645862e+07      0.0
# 4      GA49547  Washington      M             5.363076e+07  36357.0
# ...        ...         ...    ...                      ...      ...
# 12069  LA72316  California      M             2.340599e+06  71941.0
# 12070  PK87824  California      F             3.096511e+05  21604.0
# 12071  TD14365  California      M             8.163890e+05      0.0
# 12072  UP19263  California      M             7.524442e+05  21941.0
# 12073  Y167826  California      M             2.611837e+05      0.0
#
#        monthly premium auto     policy type  vehicle class  total claim amount
# ...

# %%
df=df.dropna(subset=['income', 'monthly premium auto', 'total claim amount'], how='all')
df
# Out:
#       customer       state gender  customer lifetime value   income  \
# 0      RB50392  Washington    NaN             7.714624e+05      0.0
# 1      QZ44356     Arizona      F             6.979536e+07      0.0
# 2      AI49188      Nevada      F             1.288743e+08  48767.0
# 3      WW63253  California      M             7.645862e+07      0.0
# 4      GA49547  Washington      M             5.363076e+07  36357.0
# ...        ...         ...    ...                      ...      ...
# 12069  LA72316  California      M             2.340599e+06  71941.0
# 12070  PK87824  California      F             3.096511e+05  21604.0
# 12071  TD14365  California      M             8.163890e+05      0.0
# 12072  UP19263  California      M             7.524442e+05  21941.0
# 12073  Y167826  California      M             2.611837e+05      0.0
#
#        monthly premium auto     policy type  vehicle class  total claim amount
# ...

# %%
df=df.isna().sum()
df
# Out:
# customer                     0
# state                        0
# gender                     122
# customer lifetime value      0
# income                       0
# monthly premium auto         0
# policy type                  0
# vehicle class                0
# total claim amount           0
# dtype: int64

# %%
df5 = pd.read_csv(r'C:\Users\diana\OneDrive\Bureau\Labs\python_labs\lab-customer-analysis-round-2\files_for_lab\csv_files\marketing_customer_analysis.csv')
df5
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
import datetime
from datetime import date

# %%
df5_types=df5.dtypes
df5_types
# Out:
# Unnamed: 0                         int64
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim          float64
# Months Since Policy Inception      int64
# Number of Open Complaints        float64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# ...

# %%
df5['Effective To Date']=pd.to_datetime(df5['Effective To Date'])
df5
# Out:
# C:\Users\diana\AppData\Local\Temp\ipykernel_31912\1384815822.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df5['Effective To Date']=pd.to_datetime(df5['Effective To Date'])
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# ...

# %%
df5['Month'] = df5['Effective To Date'].dt.month

# %%
df5
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
first_quarter_data = df5[(df5['Month'] >= 1) & (df5['Month'] <= 3)]
first_quarter_data
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...
